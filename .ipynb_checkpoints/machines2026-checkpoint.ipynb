# %% [markdown]
# ![jupyter](img/itq-logo.png)
#
# ## PAO25-25 - Python 01
#
# ![jupyter](img/python-logo.png)
#
# *Gabriel Salguero*
#
# ## Introducción a Python
# ### Principales Características
# - Lenguaje de Propósito general.
# - Interpretado, no compilado. Más flexible y portable.
# - Tipado dinámico.
# - Fuertemente tipado.
# - Énfasis en la legibilidad.
# - Lenguaje de alto nivel.
# - Gestión automática de memoria.
# - Multiparadigma: orientado a objetos, procedural y funcional.
# - Indentación para eliminar bloques de código.
# - Gran librería con módulos para múltiples tareas.
# - Multiplataforma.
#
# ### ¿Por qué Python?
# “Python is used in pursuits as diverse as data science, film-making, computer science education, IT management, and much more.”
#
# Kopec, D.(2019). Classic computer science problems in Python.
#
# - Uno de los lenguajes más usados en el mundo.
# - Perfecto para introducción a la programación.
# - Ecosistema amplio y comunidad participativa.
# - Incrementa la productividad: código compacto y legible.
#
# ### ¿Qué puedo hacer con Python?
# - Herramientas shell y administración de sistemas.
# - Manipulación de ficheros y ejecución de comandos.
# - Desarrollo de interfaces Gráficas de Usuario (GUIs).
# - Comunicación de red (JSON, Sockets, FTP).
# - Computación numérica, IA y Machine Learning.
#
# ### Filosofía Python

# %%
import this

# %% [markdown]
# ### Documentación
# - [Python Enhancement Proposals (PEP)](https://peps.python.org/)
# - [Python Style Guide (PEP 8)](https://peps.python.org/pep-0008/)
#
# ## Intérprete de Python y ejecución de scripts
# ### Antes de empezar
# **Formas para ejecutar código:**
# - Terminal o Shell interactivo.
# - IDEs (VSCode, PyCharm, Spyder).
# - Notebooks (Jupyter, Google Colab).
#
# ### ¿Qué es un intérprete?
# - Programa que ejecuta otros programas como capa entre el código y el hardware.
# - Implementaciones: CPython, Jython, IronPython.

# %%
# Imprimir mensaje inicial
print('Hello World')

# %% [markdown]
# ### Perspectiva del desarrollador y de Python
# - Scripts con extensión `.py`.
# - Compilación a *byte code* (ficheros `.pyc`).
# - Python Virtual Machine (PVM).

# %%
import pandas as pd
print("Librería Pandas importada correctamente.")

# %% [markdown]
# ### Performance Sample: NumPy vs Plain Python

# %%
import numpy as np 

my_arr = np.arange(10000000) 
my_list = list(range(10000000)) 

print("Arreglos y listas listos para la prueba de rendimiento.")

# %%
# %time for _ in range(10): my_arr2 = my_arr * 2
# %time for _ in range(10): my_list2 = [x * 2 for x in my_list]
